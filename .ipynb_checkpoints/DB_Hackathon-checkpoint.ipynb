# %%
import pandas as pd
import numpy as np

# %%
import xlrd
import csv

def csv_from_excel():
    wb = xlrd.open_workbook('Hackathon Dummy Data.xlsx')
    sh = wb.sheet_by_name('Team Preferences')
    your_csv_file = open('Team.csv', 'w')
    wr = csv.writer(your_csv_file, quoting=csv.QUOTE_ALL)

    for rownum in range(sh.nrows):
        wr.writerow(sh.row_values(rownum))

    your_csv_file.close()

# runs the csv_from_excel function:
csv_from_excel()

# %%
grad_df = pd.read_csv("Grad.csv")
grad_df.head(20)
# Out:
#              Graduates                                  Team Preference 1  \
# 0     Danyal Schofield                                     Tax Technology
# 1         Chanel Leech                            Post Trading Technology
# 2    Amy-Louise Conroy                            Core Trading Technology
# 3        Syed Thompson                        Legal Software Architecture
# 4       Danny Connelly                                 GTB: Trade Finance
# 5           Mia Morley                                    abFX Technology
# 6         Briana Glass                                 FX Risk Technology
# 7           Shiv Rosas                        GTB Technology Surveillance
# 8          Melody Cook                     Financial Spreading Automation
# 9        Willem Mcgill                         Enterprise Risk Technology
# 10       Tristan Hanna  Sales, Origination & Advisory Information Tech...
# 11  Annabella Crawford                                 Stategic Analytics
# 12    Florrie Thornton                                           FlowRisk
# 13       Yolanda Tyson                                     CIB Tech: Data
# 14    Caitlin Browning                               GTB Instant Payments
# 15       Everly Holman                               GTB Instant Payments
# 16         Ruth Holder                                       Mercury Team
# 17      Chelsey Magana                                      Looking Glass
# 18       Karson Waller                              Operations Automation
# 19     Arissa Mcmillan                                               CCNG
#
#                        Team Preference 2  \
# 0           Transition & Steering Office
# 1       Enterprise Security Architecture
# 2            Client Lifecycle Management
# 3                      End User Services
# 4       AFC - Financial Crime Operations
# 5               Trade Finance Operations
# 6                   GTB Instant Payments
# 7                   GTB Instant Payments
# 8                           Mercury Team
# 9                          Looking Glass
# 10                 Operations Automation
# 11                                  CCNG
# 12                           DbSyndicate
# 13  Fixed Income & Currencies Technology
# 14               Distribution Technology
# 15                         Equity Strats
# 16                 Finance & Loan Agency
# 17             Trade Services Technology
# 18           Ratings Advisory Technology
# 19                         GT Production
#
#                                     Team Preference 3  \
# 0                               Finance & Loan Agency
# 1                           Finance Control Oversight
# 2                      Financial Spreading Automation
# 3                Fixed Income & Currencies Technology
# 4                                            FlowRisk
# 5                                  FX Risk Technology
# 6                                       GT Production
# 7                             Distribution Technology
# 8                         GTB Technology Surveillance
# 9                                  GTB: Trade Finance
# 10     GTO - Data Solutions & Knowledge Visualisation
# 11                            HR Digital Development
# 12                        Legal Software Architecture
# 13                                      Looking Glass
# 14                            Distribution Technology
# 15                                       Mercury Team
# 16                              Operations Automation
# 17                            Post Trading Technology
# 18                        Ratings Advisory Technology
# 19  Sales, Origination & Advisory Information Tech...
#
#                                  Team Preference 4  \
# 0                                  abFX Technology
# 1                 AFC - Financial Crime Operations
# 2                                             BRDS
# 3                       Cash Management Technology
# 4                                             CCNG
# 5                        CIB Regulatory Adherence
# 6                                   CIB Tech: Data
# 7                      Client Lifecycle Management
# 8                          Core Trading Technology
# 9                                      DbSyndicate
# 10                         Distribution Technology
# 11                             End User Production
# 12                                   GT Production
# 13                            GTB Instant Payments
# 14                     GTB Technology Surveillance
# 15                              GTB: Trade Finance
# 16  GTO - Data Solutions & Knowledge Visualisation
# 17                         HR Digital Development
# 18                     Legal Software Architecture
# 19                                   Looking Glass
#
#                        Team Preference 5          Skill #1   Skill #2   \
# 0       Enterprise Security Architecture              Java         C++
# 1                          Equity Strats            Python  JavaScript
# 2                          Finance - GVG              Java      Python
# 3                  Finance & Loan Agency              Java         C++
# 4              Finance Control Oversight            Python  JavaScript
# 5         Financial Spreading Automation               C++         NaN
# 6   Fixed Income & Currencies Technology                C#         NaN
# 7                               FlowRisk                BA         SQL
# 8                     FX Risk Technology            Python         C++
# 9                          GT Production               NaN         NaN
# 10                  GTB Instant Payments  Machine Learning         NaN
# 11           GTB Technology Surveillance  Machine Learning         NaN
# 12                    GTB: Trade Finance                BA         SQL
# 13      AFC - Financial Crime Operations                BA      Python
# 14                                  BRDS              Java         NaN
# 15            Cash Management Technology            Python         NaN
# 16                                  CCNG               NaN         NaN
# 17             CIB Regulatory Adherence   Machine Learning      Python
# 18                        CIB Tech: Data               SQL         NaN
# 19      AFC - Financial Crime Operations              Java      Python
#
#       Skill #3
# 0   JavaScript
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7   JavaScript
# 8          NaN
# 9          NaN
# 10         NaN
# 11         NaN
# 12         NaN
# 13  JavaScript
# 14         NaN
# 15         NaN
# 16         NaN
# 17         NaN
# 18         NaN
# 19         NaN

# %%
manager_df = pd.read_csv("Team.csv")
manager_df.head()
# Out:
#                          Teams  Grad Preference 1 Grad Preference 2  \
# 0      Post Trading Technology   Danyal Schofield       Ruth Holder
# 1      Core Trading Technology       Chanel Leech    Chelsey Magana
# 2  Legal Software Architecture  Amy-Louise Conroy     Karson Waller
# 3           GTB: Trade Finance      Syed Thompson   Arissa Mcmillan
# 4              abFX Technology     Danny Connelly     Marlon Osborn
#
#   Grad Preference 3 Grad Preference 4 Grad Preference 5 Skill #1 Skill #2   \
# 0               NaN               NaN               NaN       C#       SQL
# 1        Shiv Rosas      Briana Glass               NaN      NaN       NaN
# 2       Melody Cook  Caitlin Browning               NaN      NaN       NaN
# 3     Willem Mcgill      Chanel Leech               NaN     Java       NaN
# 4     Tristan Hanna    Chelsey Magana               NaN     Java       NaN
#
#   Skill #3
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN

# %%
gradsBoard = {}
teamsBoard = {}

# %%
def find_team_index(team_name):
    for key,value in teamsBoard.items():
        if team_name == value.name:
            return key
    print("could not find a team with the specified team name")
    return None
    
def find_grad_index(grad_name):
    for key,value in gradsBoard.items():
        if grad_name == value.name:
            return key
    print("could not find a grad with the specified grad name")
    return None

# %%
class Grad:
    matched = False
    team = None
    team_name = ""
    
    def __init__(self, name, preferences, id = None, skills = ""):
        self.name = name
        self.id = id
        self.skills = skills
        self.preferences = preferences
        
    def make_proposition(self, team_name):
        key = find_team_index(team_name)
        if key != None:
            team = teamsBoard[key]
            proposition = team.test_proposition(self.name)
            
            if proposition == True:
                self.update_team(team)
        pass
    
    def update_team(self, team):
        # tell my current team I am no longer there
        if self.matched == True:
            self.team.matched = False
            self.team.grad = None
            self.team.grad_name = ""
        
        # tell my new team I am one of theirs
        self.matched = True
        self.team = team
        self.team_name = team.name
        
        pass
    
    pass

# %%
class Team:
    matched = False
    grad = None
    grad_name = ""
    
    def __init__(self, name, preferences, id = None, skills = ""):
        self.name = name
        self.id = id
        self.preferences = preferences
        self.skills = skills
        
    def test_proposition(self, prop_grad):
        proposed_grad = gradsBoard[find_grad_index(prop_grad)]
        if self.matched == False:
            print("I currently have no grad so I accept")
            print()
            self.update_grad(proposed_grad)
            return True
        else:
            if proposed_grad.name in self.preferences:
                if self.grad_name not in self.preferences:
                    print("I prefer this grad over what I currently have so I accept their proposition")
                    self.update_grad(proposed_grad)
                    return True
                else:
                    if self.preferences.index(proposed_grad.name) < self.preferences.index(self.grad_name):
                        print("I prefer this grad over what I currently have so I accept their proposition")
                        print()
                        self.update_grad(proposed_grad)
                        return True
                    print("I have no preference for this grad over what I currently have so I reject")
                    print()
                    return False
            else:
                print("I have no preference for this grad over what I currently have so I reject")
                print()
                
                return False
        
    
    def update_grad(self, grad):
#         I also need to tell the grad I currently have that he is no longer matched
        if self.matched == True:
            self.grad.matched = False
            self.grad.team = None
            self.grad.team_name = ""
        
        self.matched = True
        self.grad = grad
        self.grad_name = grad.name
        pass
    
    pass

# %%
for index, row in grad_df.iterrows():
    gradsBoard[index] = Grad(row[0], [row[1], row[2], row[3], row[4], row[5]], id = index, skills = [row[6], row[7], row[8]])

for index, row in manager_df.iterrows():
    teamsBoard[index] = Team(row[0], [row[1], row[2], row[3], row[4], row[5]], id = index, skills = [row[6], row[7], row[8]])

# %%
gradsBoard[0].preferences[0] = "Stategic Analytics"

# %%
gradsBoard.items()
# Out:
# dict_items([(0, <__main__.Grad object at 0x1142530f0>), (1, <__main__.Grad object at 0x114253080>), (2, <__main__.Grad object at 0x1142530b8>), (3, <__main__.Grad object at 0x114253128>), (4, <__main__.Grad object at 0x114253160>), (5, <__main__.Grad object at 0x114253208>), (6, <__main__.Grad object at 0x114253198>), (7, <__main__.Grad object at 0x1142531d0>), (8, <__main__.Grad object at 0x114253240>), (9, <__main__.Grad object at 0x114253278>), (10, <__main__.Grad object at 0x1142532b0>), (11, <__main__.Grad object at 0x1142532e8>), (12, <__main__.Grad object at 0x114253358>), (13, <__main__.Grad object at 0x114253320>), (14, <__main__.Grad object at 0x114253390>), (15, <__main__.Grad object at 0x1142533c8>), (16, <__main__.Grad object at 0x114253400>), (17, <__main__.Grad object at 0x114253438>), (18, <__main__.Grad object at 0x114253470>), (19, <__main__.Grad object at 0x1142536a0>), (20, <__main__.Grad object at 0x114253780>), (21, <__main__.Grad object at 0x114253898>), (22, <__main__.Grad object at 0x114253978>), (23, <__main__.Grad object at 0x1142538d0>), (24, <__main__.Grad object at 0x114253908>), (25, <__main__.Grad object at 0x114253940>), (26, <__main__.Grad object at 0x1142539b0>), (27, <__main__.Grad object at 0x114253a90>), (28, <__main__.Grad object at 0x1142539e8>), (29, <__main__.Grad object at 0x114253a20>), (30, <__main__.Grad object at 0x114253a58>), (31, <__main__.Grad object at 0x114253ac8>), (32, <__main__.Grad object at 0x114253ba8>), (33, <__main__.Grad object at 0x114253b00>), (34, <__main__.Grad object at 0x114253b38>), (35, <__main__.Grad object at 0x114253b70>), (36, <__main__.Grad object at 0x1142537b8>)])

# %%
# First round
complete = False
for key,value in gradsBoard.items():
    value.make_proposition(value.preferences[0])
# Out:
#   File "<ipython-input-12-a4332075c991>", line 3
#     for key,value in gradsBoard.items():
#     ^
# IndentationError: unexpected indent

# %%
find_team_index("Tax Technology")

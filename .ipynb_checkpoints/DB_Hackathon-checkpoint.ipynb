# %%
import pandas as pd
import numpy as np

# %%
import xlrd
import csv

def csv_from_excel():
    wb = xlrd.open_workbook('latest.xlsx')
    sh = wb.sheet_by_name('Team Preferences')
    your_csv_file = open('Team.csv', 'w')
    wr = csv.writer(your_csv_file, quoting=csv.QUOTE_ALL)

    for rownum in range(sh.nrows):
        wr.writerow(sh.row_values(rownum))

    your_csv_file.close()

# runs the csv_from_excel function:
csv_from_excel()

# %%
grad_df = pd.read_csv("Grad.csv")
grad_df.head(37)
# Out:
#              Graduates                                  Team Preference 1  \
# 0     Danyal Schofield                                     Tax Technology
# 1         Chanel Leech                            Post Trading Technology
# 2    Amy-Louise Conroy                            Core Trading Technology
# 3        Syed Thompson                        Legal Software Architecture
# 4       Danny Connelly                                 GTB: Trade Finance
# 5           Mia Morley                                    abFX Technology
# 6         Briana Glass                                 FX Risk Technology
# 7           Shiv Rosas                        GTB Technology Surveillance
# 8          Melody Cook                     Financial Spreading Automation
# 9        Willem Mcgill                         Enterprise Risk Technology
# 10       Tristan Hanna  Sales, Origination & Advisory Information Tech...
# 11  Annabella Crawford                                 Stategic Analytics
# 12    Florrie Thornton                                           FlowRisk
# 13       Yolanda Tyson                                     CIB Tech: Data
# 14    Caitlin Browning                               GTB Instant Payments
# 15       Everly Holman                               GTB Instant Payments
# 16         Ruth Holder                                       Mercury Team
# 17      Chelsey Magana                                      Looking Glass
# 18       Karson Waller                              Operations Automation
# 19     Arissa Mcmillan                                               CCNG
# 20       Marlon Osborn                                        DbSyndicate
# 21     Courtnie Barker               Fixed Income & Currencies Technology
# 22      Mathias Becker                            Distribution Technology
# 23       Rio Wilkinson                                      Equity Strats
# 24        Vishal Logan                              Finance & Loan Agency
# 25        Lauren Chang                               GTB Instant Payments
# 26          Alex Hulme                        Ratings Advisory Technology
# 27         Aiza Currie                                      GT Production
# 28       Maryam Lennon                                     Test Delivery
# 29          Ivan Nixon     GTO - Data Solutions & Knowledge Visualisation
# 30         Lesley West                      Trade Finance Deal Management
# 31         Aida Curran                         Cash Management Technology
# 32     Presley Sargent                          CIB Regulatory Adherence
# 33       Anjali Bowden                            HR Digital Development
# 34      Derrick Sadler                                      Finance - GVG
# 35       Nabilah Miles                                End User Production
# 36         Jarod Arias            Vulnerability & Compliance Remediation
#
#                                  Team Preference 2  \
# 0                     Transition & Steering Office
# 1                 Enterprise Security Architecture
# 2                      Client Lifecycle Management
# 3                                End User Services
# 4                 AFC - Financial Crime Operations
# 5                         Trade Finance Operations
# 6                             GTB Instant Payments
# 7                             GTB Instant Payments
# 8                                     Mercury Team
# 9                                    Looking Glass
# 10                           Operations Automation
# 11                                            CCNG
# 12                                     DbSyndicate
# 13            Fixed Income & Currencies Technology
# 14                         Distribution Technology
# 15                                   Equity Strats
# 16                           Finance & Loan Agency
# 17                       Trade Services Technology
# 18                     Ratings Advisory Technology
# 19                                   GT Production
# 20                                  Test Delivery
# 21  GTO - Data Solutions & Knowledge Visualisation
# 22                   Trade Finance Deal Management
# 23                      Cash Management Technology
# 24                       CIB Regulatory Adherence
# 25                         HR Digital Development
# 26                                   Finance - GVG
# 27                             End User Production
# 28         Vulnerability & Compliance Remediation
# 29                    Transition & Steering Office
# 30                Enterprise Security Architecture
# 31                     Client Lifecycle Management
# 32                               End User Services
# 33                AFC - Financial Crime Operations
# 34                        Trade Finance Operations
# 35                            GTB Instant Payments
# 36                                            BRDS
#
#                                     Team Preference 3  \
# 0                               Finance & Loan Agency
# 1                           Finance Control Oversight
# 2                      Financial Spreading Automation
# 3                Fixed Income & Currencies Technology
# 4                                            FlowRisk
# 5                                  FX Risk Technology
# 6                                       GT Production
# 7                             Distribution Technology
# 8                         GTB Technology Surveillance
# 9                                  GTB: Trade Finance
# 10     GTO - Data Solutions & Knowledge Visualisation
# 11                            HR Digital Development
# 12                        Legal Software Architecture
# 13                                      Looking Glass
# 14                            Distribution Technology
# 15                                       Mercury Team
# 16                              Operations Automation
# 17                            Post Trading Technology
# 18                        Ratings Advisory Technology
# 19  Sales, Origination & Advisory Information Tech...
# 20                                 Stategic Analytics
# 21                                     Tax Technology
# 22                                     Test Delivery
# 23                      Trade Finance Deal Management
# 24                           Trade Finance Operations
# 25                          Trade Services Technology
# 26                       Transition & Steering Office
# 27            Vulnerability & Compliance Remediation
# 28                          CIB Regulatory Adherence
# 29                                     CIB Tech: Data
# 30                        Client Lifecycle Management
# 31                            Core Trading Technology
# 32                                        DbSyndicate
# 33                            Distribution Technology
# 34                                End User Production
# 35                                  End User Services
# 36                         Enterprise Risk Technology
#
#                                     Team Preference 4  \
# 0                                     abFX Technology
# 1                    AFC - Financial Crime Operations
# 2                                                BRDS
# 3                          Cash Management Technology
# 4                                                CCNG
# 5                           CIB Regulatory Adherence
# 6                                      CIB Tech: Data
# 7                         Client Lifecycle Management
# 8                             Core Trading Technology
# 9                                         DbSyndicate
# 10                            Distribution Technology
# 11                                End User Production
# 12                                      GT Production
# 13                               GTB Instant Payments
# 14                        GTB Technology Surveillance
# 15                                 GTB: Trade Finance
# 16     GTO - Data Solutions & Knowledge Visualisation
# 17                            HR Digital Development
# 18                        Legal Software Architecture
# 19                                      Looking Glass
# 20                               GTB Instant Payments
# 21                                       Mercury Team
# 22                              Operations Automation
# 23                            Post Trading Technology
# 24                        Ratings Advisory Technology
# 25  Sales, Origination & Advisory Information Tech...
# 26                                       Mercury Team
# 27                                      Looking Glass
# 28                              Operations Automation
# 29                                               CCNG
# 30                                        DbSyndicate
# 31               Fixed Income & Currencies Technology
# 32                            Distribution Technology
# 33                                      Equity Strats
# 34                              Finance & Loan Agency
# 35                          Trade Services Technology
# 36                        Ratings Advisory Technology
#
#                                  Team Preference 5          Skill #1  \
# 0                 Enterprise Security Architecture              Java
# 1                                    Equity Strats            Python
# 2                                    Finance - GVG              Java
# 3                            Finance & Loan Agency              Java
# 4                        Finance Control Oversight            Python
# 5                   Financial Spreading Automation               C++
# 6             Fixed Income & Currencies Technology                C#
# 7                                         FlowRisk                BA
# 8                               FX Risk Technology            Python
# 9                                    GT Production               NaN
# 10                            GTB Instant Payments  Machine Learning
# 11                     GTB Technology Surveillance  Machine Learning
# 12                              GTB: Trade Finance                BA
# 13                AFC - Financial Crime Operations                BA
# 14                                            BRDS              Java
# 15                      Cash Management Technology            Python
# 16                                            CCNG               NaN
# 17                       CIB Regulatory Adherence   Machine Learning
# 18                                  CIB Tech: Data               SQL
# 19                AFC - Financial Crime Operations              Java
# 20                                            BRDS              Java
# 21                      Cash Management Technology        JavaScript
# 22                                            CCNG              Java
# 23                       CIB Regulatory Adherence             Python
# 24                                  CIB Tech: Data                C#
# 25                AFC - Financial Crime Operations               NaN
# 26                                            BRDS                BA
# 27                      Cash Management Technology              Java
# 28                                            CCNG            Python
# 29                       CIB Regulatory Adherence                 BA
# 30                                  CIB Tech: Data              Java
# 31                     GTB Technology Surveillance            Python
# 32                              GTB: Trade Finance        JavaScript
# 33  GTO - Data Solutions & Knowledge Visualisation               NaN
# 34                         HR Digital Development         JavaScript
# 35                     Legal Software Architecture              Java
# 36                                   Looking Glass              Java
#
#      Skill #2     Skill #3
# 0          C++  JavaScript
# 1   JavaScript         NaN
# 2       Python         NaN
# 3          C++         NaN
# 4   JavaScript         NaN
# 5          NaN         NaN
# 6          NaN         NaN
# 7          SQL  JavaScript
# 8          C++         NaN
# 9          NaN         NaN
# 10         NaN         NaN
# 11         NaN         NaN
# 12         SQL         NaN
# 13      Python  JavaScript
# 14         NaN         NaN
# 15         NaN         NaN
# 16         NaN         NaN
# 17      Python         NaN
# 18         NaN         NaN
# 19      Python         NaN
# 20         NaN         NaN
# 21     Angular         NaN
# 22      Python         NaN
# 23         NaN         NaN
# 24         NaN         NaN
# 25         NaN         NaN
# 26         SQL         NaN
# 27         NaN         NaN
# 28     Angular         NaN
# 29         NaN         NaN
# 30      Python         NaN
# 31         NaN         NaN
# 32     Angular         NaN
# 33         NaN         NaN
# 34     Angular         NaN
# 35         NaN         NaN
# 36         NaN         NaN

# %%
manager_df = pd.read_csv("Team.csv")
manager_df.head(40)
# Out:
#                                                 Teams   Grad Preference 1  \
# 0                             Post Trading Technology    Danyal Schofield
# 1                             Core Trading Technology        Chanel Leech
# 2                         Legal Software Architecture   Amy-Louise Conroy
# 3                                  GTB: Trade Finance       Syed Thompson
# 4                                     abFX Technology      Danny Connelly
# 5                                  FX Risk Technology          Mia Morley
# 6                         GTB Technology Surveillance        Briana Glass
# 7                      Financial Spreading Automation          Shiv Rosas
# 8                          Enterprise Risk Technology         Melody Cook
# 9   Sales, Origination & Advisory Information Tech...       Willem Mcgill
# 10                                 Stategic Analytics       Tristan Hanna
# 11                                           FlowRisk  Annabella Crawford
# 12                                     CIB Tech: Data    Florrie Thornton
# 13                                               BRDS       Yolanda Tyson
# 14                               GTB Instant Payments                 NaN
# 15                                       Mercury Team       Everly Holman
# 16                                      Looking Glass         Ruth Holder
# 17                              Operations Automation      Chelsey Magana
# 18                                               CCNG       Karson Waller
# 19                                        DbSyndicate     Arissa Mcmillan
# 20               Fixed Income & Currencies Technology       Marlon Osborn
# 21                            Distribution Technology     Courtnie Barker
# 22                                      Equity Strats      Mathias Becker
# 23                              Finance & Loan Agency       Rio Wilkinson
# 24                          Trade Services Technology      Danny Connelly
# 25                        Ratings Advisory Technology         Melody Cook
# 26                                      GT Production       Karson Waller
# 27                                     Test Delivery       Derrick Sadler
# 28     GTO - Data Solutions & Knowledge Visualisation       Nabilah Miles
# 29                      Trade Finance Deal Management                 NaN
# 30                         Cash Management Technology       Tristan Hanna
# 31                          CIB Regulatory Adherence   Annabella Crawford
# 32                            HR Digital Development       Danny Connelly
# 33                                      Finance - GVG       Maryam Lennon
# 34                                End User Production          Ivan Nixon
# 35            Vulnerability & Compliance Remediation          Lesley West
# 36                       Transition & Steering Office         Aida Curran
# 37                   Enterprise Security Architecture     Presley Sargent
# 38                        Client Lifecycle Management       Anjali Bowden
# 39                                  End User Services    Florrie Thornton
#
#      Grad Preference 2   Grad Preference 3 Grad Preference 4  \
# 0          Ruth Holder                 NaN               NaN
# 1       Chelsey Magana          Shiv Rosas      Briana Glass
# 2        Karson Waller         Melody Cook  Caitlin Browning
# 3      Arissa Mcmillan       Willem Mcgill      Chanel Leech
# 4        Marlon Osborn       Tristan Hanna    Chelsey Magana
# 5      Courtnie Barker  Annabella Crawford       Ruth Holder
# 6       Mathias Becker    Florrie Thornton        Shiv Rosas
# 7        Rio Wilkinson    Florrie Thornton     Syed Thompson
# 8         Vishal Logan       Syed Thompson     Tristan Hanna
# 9         Lauren Chang       Willem Mcgill      Vishal Logan
# 10          Alex Hulme        Vishal Logan     Willem Mcgill
# 11         Aiza Currie   Amy-Louise Conroy     Yolanda Tyson
# 12       Maryam Lennon        Vishal Logan               NaN
# 13          Ivan Nixon      Derrick Sadler               NaN
# 14                 NaN                 NaN               NaN
# 15         Aida Curran          Mia Morley               NaN
# 16     Presley Sargent     Presley Sargent               NaN
# 17       Anjali Bowden          Mia Morley               NaN
# 18      Derrick Sadler       Yolanda Tyson               NaN
# 19       Nabilah Miles    Caitlin Browning               NaN
# 20         Jarod Arias                 NaN               NaN
# 21   Amy-Louise Conroy                 NaN               NaN
# 22       Syed Thompson                 NaN               NaN
# 23      Danny Connelly   Amy-Louise Conroy               NaN
# 24          Mia Morley       Syed Thompson               NaN
# 25        Briana Glass      Danny Connelly               NaN
# 26          Shiv Rosas          Mia Morley               NaN
# 27         Melody Cook        Briana Glass               NaN
# 28                 NaN                 NaN               NaN
# 29                 NaN                 NaN               NaN
# 30  Annabella Crawford       Willem Mcgill               NaN
# 31    Florrie Thornton       Tristan Hanna               NaN
# 32       Yolanda Tyson  Annabella Crawford     Rio Wilkinson
# 33    Caitlin Browning    Florrie Thornton      Vishal Logan
# 34       Everly Holman       Yolanda Tyson      Lauren Chang
# 35    Danyal Schofield       Karson Waller        Alex Hulme
# 36        Chanel Leech     Arissa Mcmillan               NaN
# 37   Amy-Louise Conroy       Marlon Osborn     Maryam Lennon
# 38       Syed Thompson     Courtnie Barker        Ivan Nixon
# 39      Danny Connelly          Ivan Nixon               NaN
#
#    Grad Preference 5    Skill #1         Skill #2       Skill #3
# 0                NaN          C#               SQL           NaN
# 1                NaN         NaN               NaN           NaN
# 2                NaN         NaN               NaN           NaN
# 3                NaN        Java               NaN           NaN
# 4                NaN        Java               NaN           NaN
# 5                NaN      Python               NaN           NaN
# 6         Alex Hulme        Java               SQL           NaN
# 7        Aiza Currie         SQL               NaN           NaN
# 8      Maryam Lennon      Python               NaN           NaN
# 9         Ivan Nixon      Python               NaN           NaN
# 10               NaN        Java               NaN           NaN
# 11               NaN         NaN               NaN           NaN
# 12               NaN         NaN               NaN           NaN
# 13               NaN        Java               SQL           NaN
# 14               NaN          C#               NaN           NaN
# 15               NaN          C#        JavaScript           NaN
# 16               NaN        Java               NaN           NaN
# 17               NaN      Python  Machine Learning  Data science
# 18               NaN         C++               KDB           NaN
# 19               NaN        Java               SQL           NaN
# 20               NaN        Java               NaN           NaN
# 21               NaN        Java               SQL           NaN
# 22               NaN         NaN               NaN           NaN
# 23               NaN         NaN               NaN           NaN
# 24               NaN         NaN               NaN           NaN
# 25               NaN         NaN               NaN           NaN
# 26               NaN        Java               NaN           NaN
# 27               NaN          C#               NaN           NaN
# 28               NaN  JavaScript             React           SQL
# 29               NaN         NaN               NaN           NaN
# 30               NaN        Java               NaN           NaN
# 31               NaN          C#               NaN           NaN
# 32               NaN        Java               NaN           NaN
# 33               NaN          C#               NaN           NaN
# 34               NaN          C#               NaN           NaN
# 35               NaN  JavaScript             React        Python
# 36               NaN        Java               SQL           NaN
# 37               NaN        Java               NaN           NaN
# 38               NaN           C               NaN           NaN
# 39               NaN         NaN               NaN           NaN

# %%
gradsBoard = {}
teamsBoard = {}

# %%
def find_team_index(team_name):
    for key,value in teamsBoard.items():
        if team_name == value.name:
            return key
    print("could not find a team with the specified team name")
    return None
    
def find_grad_index(grad_name):
    for key,value in gradsBoard.items():
        if grad_name == value.name:
            return key
    print("could not find a grad with the specified grad name")
    return None

# %%
class Grad:
    matched = False
    team = None
    team_name = ""
    index_to_apply = 0
    
    def __init__(self, name, preferences, id = None, skills = ""):
        self.name = name
        self.id = id
        self.skills = skills
        self.preferences = preferences
        
    def make_proposition(self, team_name):
        key = find_team_index(team_name)
        if key != None:
            team = teamsBoard[key]
            proposition = team.test_proposition(self.name)
            
            if proposition == True:
                self.update_team(team)
            else:
                self.index_to_apply = self.index_to_apply + 1
                if self.index_to_apply == len(self.preferences):
                    self.matched = True
        pass
    
    def update_team(self, team):
        # tell my current team I am no longer there
        if self.matched == True:
            self.team.matched = False
            self.team.grad = None
            self.team.grad_name = ""
        
        # tell my new team I am one of theirs
        self.matched = True
        self.team = team
        self.team_name = team.name
        
        pass
    
    pass

# %%
class Team:
    matched = False
    grad = None
    grad_name = ""
    
    def __init__(self, name, preferences, id = None, skills = ""):
        self.name = name
        self.id = id
        self.preferences = preferences
        self.skills = skills
        
    def test_proposition(self, prop_grad):
        proposed_grad = gradsBoard[find_grad_index(prop_grad)]
        if self.matched == False:
            print("I currently have no grad so I accept")
            print()
            self.update_grad(proposed_grad)
            return True
        else:
            if proposed_grad.name in self.preferences:
                if self.grad_name not in self.preferences:
                    print("I prefer this grad over what I currently have so I accept their proposition")
                    self.update_grad(proposed_grad)
                    return True
                else:
                    if self.preferences.index(proposed_grad.name) < self.preferences.index(self.grad_name):
                        print("I prefer this grad over what I currently have so I accept their proposition")
                        print()
                        self.update_grad(proposed_grad)
                        return True
                    print("I have no preference for this grad over what I currently have so I reject")
                    print()
                    return False
            else:
                print("I have no preference for this grad over what I currently have so I reject")
                print()
                
                return False
        
    
    def update_grad(self, grad):
#         I also need to tell the grad I currently have that he is no longer matched
        if self.matched == True:
            self.grad.matched = False
            self.grad.team = None
            self.grad.team_name = ""
            self.grad.index_to_apply = self.grad.index_to_apply + 1
            
            if self.grad.index_to_apply == len(self.grad.preferences):
                self.grad.matched == True
        
        self.matched = True
        self.grad = grad
        self.grad_name = grad.name
        pass
    
    pass

# %%
for index, row in grad_df.iterrows():
    gradsBoard[index] = Grad(row[0], [row[1], row[2], row[3], row[4], row[5]], id = index, skills = [row[6], row[7], row[8]])

for index, row in manager_df.iterrows():
    teamsBoard[index] = Team(row[0], [row[1], row[2], row[3], row[4], row[5]], id = index, skills = [row[6], row[7], row[8]])

# %%
gradsBoard[0].preferences[0] = "Stategic Analytics"

# %%
gradsBoard.items()
# Out:
# dict_items([(0, <__main__.Grad object at 0x1204a7278>), (1, <__main__.Grad object at 0x1204a7208>), (2, <__main__.Grad object at 0x1204a7240>), (3, <__main__.Grad object at 0x1204a72b0>), (4, <__main__.Grad object at 0x1204a72e8>), (5, <__main__.Grad object at 0x1204a7320>), (6, <__main__.Grad object at 0x1204a7358>), (7, <__main__.Grad object at 0x1204a7390>), (8, <__main__.Grad object at 0x1204a73c8>), (9, <__main__.Grad object at 0x1204a7400>), (10, <__main__.Grad object at 0x1204a7438>), (11, <__main__.Grad object at 0x1204a7470>), (12, <__main__.Grad object at 0x1204a74a8>), (13, <__main__.Grad object at 0x1204a74e0>), (14, <__main__.Grad object at 0x1204a7518>), (15, <__main__.Grad object at 0x1204a7550>), (16, <__main__.Grad object at 0x1204a7588>), (17, <__main__.Grad object at 0x1204a75c0>), (18, <__main__.Grad object at 0x1204a75f8>), (19, <__main__.Grad object at 0x1204a7630>), (20, <__main__.Grad object at 0x1204a7668>), (21, <__main__.Grad object at 0x1204a76a0>), (22, <__main__.Grad object at 0x1204a76d8>), (23, <__main__.Grad object at 0x1204a7710>), (24, <__main__.Grad object at 0x1204a7748>), (25, <__main__.Grad object at 0x1204a7780>), (26, <__main__.Grad object at 0x1204a77b8>), (27, <__main__.Grad object at 0x1204a77f0>), (28, <__main__.Grad object at 0x1204a7828>), (29, <__main__.Grad object at 0x1204a7860>), (30, <__main__.Grad object at 0x1204a7898>), (31, <__main__.Grad object at 0x1204a78d0>), (32, <__main__.Grad object at 0x1204a7908>), (33, <__main__.Grad object at 0x1204a7940>), (34, <__main__.Grad object at 0x1204a7978>), (35, <__main__.Grad object at 0x1204a79b0>), (36, <__main__.Grad object at 0x1204a79e8>)])

# %%
# First round
# complete = False
# for key,value in gradsBoard.items():
#     value.make_proposition(value.preferences[0])
        
complete = False
pref_order = 0
while complete == False:
    
    for key,value in gradsBoard.items():
        if value.matched == False:
            value.make_proposition(value.preferences[value.index_to_apply])
    
    complete = True
    
    for key,value in gradsBoard.items():
        if value.matched == False:
            complete = False
            break
# Out:
# I currently have no grad so I accept
#
# I currently have no grad so I accept
#
# I currently have no grad so I accept
#
# I currently have no grad so I accept
#
# I currently have no grad so I accept
#
# I currently have no grad so I accept
#
# I currently have no grad so I accept
#
# I currently have no grad so I accept
#
# I currently have no grad so I accept
#
# I currently have no grad so I accept
#
# I currently have no grad so I accept
#
# I have no preference for this grad over what I currently have so I reject
#
# I currently have no grad so I accept
#
# I currently have no grad so I accept
#
# I currently have no grad so I accept
#
# I have no preference for this grad over what I currently have so I reject
#
# I currently have no grad so I accept
#
# I currently have no grad so I accept
#
# I currently have no grad so I accept
#
# I currently have no grad so I accept
#
# I currently have no grad so I accept
#
# I currently have no grad so I accept
#
# I currently have no grad so I accept
#
# I currently have no grad so I accept
#
# I currently have no grad so I accept
#
# I have no preference for this grad over what I currently have so I reject
#
# I currently have no grad so I accept
#
# I currently have no grad so I accept
#
# I currently have no grad so I accept
#
# I currently have no grad so I accept
#
# I currently have no grad so I accept
#
# I currently have no grad so I accept
#
# I currently have no grad so I accept
#
# I currently have no grad so I accept
#
# I currently have no grad so I accept
#
# I currently have no grad so I accept
#
# I currently have no grad so I accept
#
# I have no preference for this grad over what I currently have so I reject
#
# I have no preference for this grad over what I currently have so I reject
#
# I have no preference for this grad over what I currently have so I reject
#
# I prefer this grad over what I currently have so I accept their proposition
# I prefer this grad over what I currently have so I accept their proposition
# I have no preference for this grad over what I currently have so I reject
#
# I currently have no grad so I accept
#
# I currently have no grad so I accept
#
# I have no preference for this grad over what I currently have so I reject
#
# I have no preference for this grad over what I currently have so I reject
#
# I have no preference for this grad over what I currently have so I reject

# %%
find_team_index("Tax Technology")
# Out:
# could not find a team with the specified team name

# %%
data = []
for key,value in gradsBoard.items():
    data.append(value.team_name)
data

myset = set(data)
print(len(myset))
print(len(data))
data
# Out:
# 37
# 37
# ['Stategic Analytics',
#  'Post Trading Technology',
#  'Core Trading Technology',
#  'Legal Software Architecture',
#  'GTB: Trade Finance',
#  'abFX Technology',
#  'FX Risk Technology',
#  'GTB Technology Surveillance',
#  'Financial Spreading Automation',
#  'Enterprise Risk Technology',
#  'Sales, Origination & Advisory Information Technology',
#  'HR Digital Development ',
#  'FlowRisk',
#  'CIB Tech: Data',
#  'GTB Instant Payments',
#  'Mercury Team',
#  '',
#  'Looking Glass',
#  'Operations Automation',
#  'CCNG',
#  'DbSyndicate',
#  'Fixed Income & Currencies Technology',
#  'Distribution Technology',
#  'Equity Strats',
#  'Finance & Loan Agency',
#  'Trade Services Technology',
#  'Ratings Advisory Technology',
#  'GT Production',
#  'Test Delivery ',
#  'GTO - Data Solutions & Knowledge Visualisation',
#  'Trade Finance Deal Management',
#  'Cash Management Technology',
#  'CIB Regulatory Adherence ',
#  'AFC - Financial Crime Operations',
#  'Finance - GVG',
#  'End User Production',
#  'Vulnerability & Compliance Remediation ']

# %%
data = []
for key,value in gradsBoard.items():
    print(value.name + " - is in the team : " + value.team_name)
# Out:
# Danyal Schofield - is in the team : Stategic Analytics
# Chanel Leech - is in the team : Post Trading Technology
# Amy-Louise Conroy - is in the team : Core Trading Technology
# Syed Thompson - is in the team : Legal Software Architecture
# Danny Connelly - is in the team : GTB: Trade Finance
# Mia Morley - is in the team : abFX Technology
# Briana Glass - is in the team : FX Risk Technology
# Shiv Rosas - is in the team : GTB Technology Surveillance
# Melody Cook - is in the team : Financial Spreading Automation
# Willem Mcgill - is in the team : Enterprise Risk Technology
# Tristan Hanna - is in the team : Sales, Origination & Advisory Information Technology
# Annabella Crawford - is in the team : HR Digital Development
# Florrie Thornton - is in the team : FlowRisk
# Yolanda Tyson - is in the team : CIB Tech: Data
# Caitlin Browning - is in the team : GTB Instant Payments
# Everly Holman - is in the team : Mercury Team
# Ruth Holder - is in the team :
# Chelsey Magana - is in the team : Looking Glass
# Karson Waller - is in the team : Operations Automation
# Arissa Mcmillan - is in the team : CCNG
# Marlon Osborn - is in the team : DbSyndicate
# Courtnie Barker - is in the team : Fixed Income & Currencies Technology
# Mathias Becker - is in the team : Distribution Technology
# Rio Wilkinson - is in the team : Equity Strats
# Vishal Logan - is in the team : Finance & Loan Agency
# Lauren Chang - is in the team : Trade Services Technology
# Alex Hulme - is in the team : Ratings Advisory Technology
# Aiza Currie - is in the team : GT Production
# Maryam Lennon - is in the team : Test Delivery
# Ivan Nixon - is in the team : GTO - Data Solutions & Knowledge Visualisation
# Lesley West - is in the team : Trade Finance Deal Management
# Aida Curran - is in the team : Cash Management Technology
# Presley Sargent - is in the team : CIB Regulatory Adherence
# Anjali Bowden - is in the team : AFC - Financial Crime Operations
# Derrick Sadler - is in the team : Finance - GVG
# Nabilah Miles - is in the team : End User Production
# Jarod Arias - is in the team : Vulnerability & Compliance Remediation

# %%
grad_df[["Graduates", "Team Preference 1"]]
# Out:
#              Graduates                                  Team Preference 1
# 0     Danyal Schofield                                     Tax Technology
# 1         Chanel Leech                            Post Trading Technology
# 2    Amy-Louise Conroy                            Core Trading Technology
# 3        Syed Thompson                        Legal Software Architecture
# 4       Danny Connelly                                 GTB: Trade Finance
# 5           Mia Morley                                    abFX Technology
# 6         Briana Glass                                 FX Risk Technology
# 7           Shiv Rosas                        GTB Technology Surveillance
# 8          Melody Cook                     Financial Spreading Automation
# 9        Willem Mcgill                         Enterprise Risk Technology
# 10       Tristan Hanna  Sales, Origination & Advisory Information Tech...
# 11  Annabella Crawford                                 Stategic Analytics
# 12    Florrie Thornton                                           FlowRisk
# 13       Yolanda Tyson                                     CIB Tech: Data
# 14    Caitlin Browning                               GTB Instant Payments
# 15       Everly Holman                               GTB Instant Payments
# 16         Ruth Holder                                       Mercury Team
# 17      Chelsey Magana                                      Looking Glass
# 18       Karson Waller                              Operations Automation
# 19     Arissa Mcmillan                                               CCNG
# 20       Marlon Osborn                                        DbSyndicate
# 21     Courtnie Barker               Fixed Income & Currencies Technology
# 22      Mathias Becker                            Distribution Technology
# 23       Rio Wilkinson                                      Equity Strats
# 24        Vishal Logan                              Finance & Loan Agency
# 25        Lauren Chang                               GTB Instant Payments
# 26          Alex Hulme                        Ratings Advisory Technology
# 27         Aiza Currie                                      GT Production
# 28       Maryam Lennon                                     Test Delivery
# 29          Ivan Nixon     GTO - Data Solutions & Knowledge Visualisation
# 30         Lesley West                      Trade Finance Deal Management
# 31         Aida Curran                         Cash Management Technology
# 32     Presley Sargent                          CIB Regulatory Adherence
# 33       Anjali Bowden                            HR Digital Development
# 34      Derrick Sadler                                      Finance - GVG
# 35       Nabilah Miles                                End User Production
# 36         Jarod Arias            Vulnerability & Compliance Remediation

# %%
# Second round

# complete = False
# for key,value in gradsBoard.items():
#     if value.matched == False:
#         value.make_proposition(value.preferences[1])

# %%
# complete = False
# pref_order = 0
# while complete == False:
    
#     for key,value in gradsBoard.items():
#     if value.matched == False:
#         value.make_proposition(value.preferences[pref_order])
    
#     complete = True
    
#     for key,value in gradsBoard.items():
#         if value.matchef == False:
#             pref_order = pref_order + 1
#             complete = False
#             break
